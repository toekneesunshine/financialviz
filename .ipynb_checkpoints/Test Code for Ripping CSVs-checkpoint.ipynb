# %%
import os

# %%
from urllib import request

websiteLink = "https://www.google.com/finance/historical?output=csv&q="
token = "UAL"

# Retrieve the webpage as a string
response = request.urlopen(websiteLink + UAL)
csv = response.read()

# Save the string to a file
csvstr = str(csv).strip("b'")

lines = csvstr.split("\\n")
f = open("historical.csv", "w")
for line in lines:
   f.write(line + "\n")
f.close()
